# %%
from deepface import DeepFace
import re
# Out:
# WARNING:tensorflow:From c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 24-06-16 14:56:58 - Directory C:\Users\Iga Miller/.deepface created
# 24-06-16 14:56:58 - Directory C:\Users\Iga Miller/.deepface/weights created

# %%
def authenticate_user(image_path):
    result = DeepFace.find(image_path, db_path='database')

    distance = result[0]['distance'][0]
    person = ' '.join((result[0]['identity'][0]).split('\\')[-1].split('_')[:2])
    max_distance = 0.5

    print('\n-------------- Authentication --------------\n')

    print(f'Distance: {distance}')
    if distance <= max_distance:
        print(f'Authentication confirmed. Welcome {person}!')
    else:
        print('Authentication DENIED')
        
    return result

# %%
result = authenticate_user('dataset/Adam_Sandler/test_positive/Adam_Sandler_1088_560.jpeg')
# Out:
# 24-06-16 15:02:02 - Found 6946 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations:   0%|          | 0/6946 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result = authenticate_user('dataset/Adam_Sandler/test_positive/Adam_Sandler_1088_560.jpeg')
#
# Cell In[7], line 2, in authenticate_user(image_path)
#       1 def authenticate_user(image_path):
# ----> 2     result = DeepFace.find(image_path, db_path='database')
#       4     distance = result[0]['distance'][0]
#       5     person = ' '.join((result[0]['identity'][0]).split('\\')[-1].split('_')[:2])
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\DeepFace.py:336, in find(img_path, db_path, model_name, distance_metric, enforce_detection, detector_backend, align, expand_percentage, threshold, normalization, silent, refresh_database, anti_spoofing)
#     259 def find(
#     260     img_path: Union[str, np.ndarray],
#     261     db_path: str,
#    (...)
#     272     anti_spoofing: bool = False,
#     273 ) -> List[pd.DataFrame]:
#     274     """
#     275     Identify individuals in a database
#     276     Args:
#    (...)
#     334                 specified model and distance metric
#     335     """
# --> 336     return recognition.find(
#     337         img_path=img_path,
#     338         db_path=db_path,
#     339         model_name=model_name,
#     340         distance_metric=distance_metric,
#     341         enforce_detection=enforce_detection,
#     342         detector_backend=detector_backend,
#     343         align=align,
#     344         expand_percentage=expand_percentage,
#     345         threshold=threshold,
#     346         normalization=normalization,
#     347         silent=silent,
#     348         refresh_database=refresh_database,
#     349         anti_spoofing=anti_spoofing,
#     350     )
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\modules\recognition.py:207, in find(img_path, db_path, model_name, distance_metric, enforce_detection, detector_backend, align, expand_percentage, threshold, normalization, silent, refresh_database, anti_spoofing)
#     205 # find representations for new images
#     206 if len(new_images) > 0:
# --> 207     representations += __find_bulk_embeddings(
#     208         employees=new_images,
#     209         model_name=model_name,
#     210         detector_backend=detector_backend,
#     211         enforce_detection=enforce_detection,
#     212         align=align,
#     213         expand_percentage=expand_percentage,
#     214         normalization=normalization,
#     215         silent=silent,
#     216     )  # add new images
#     217     must_save_pickle = True
#     219 if must_save_pickle:
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\modules\recognition.py:393, in __find_bulk_embeddings(employees, model_name, detector_backend, enforce_detection, align, expand_percentage, normalization, silent)
#     391 img_content = img_obj["face"]
#     392 img_region = img_obj["facial_area"]
# --> 393 embedding_obj = representation.represent(
#     394     img_path=img_content,
#     395     model_name=model_name,
#     396     enforce_detection=enforce_detection,
#     397     detector_backend="skip",
#     398     align=align,
#     399     normalization=normalization,
#     400 )
#     402 img_representation = embedding_obj[0]["embedding"]
#     403 representations.append(
#     404     {
#     405         "identity": employee,
#    (...)
#     412     }
#     413 )
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\modules\representation.py:65, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing)
#      23 """
#      24 Represent facial images as multi-dimensional vector embeddings.
#      25
#    (...)
#      61         to 'skip', the confidence will be 0 and is nonsensical.
#      62 """
#      63 resp_objs = []
# ---> 65 model: FacialRecognition = modeling.build_model(model_name)
#      67 # ---------------------------------
#      68 # we have run pre-process in verification. so, this can be skipped if it is coming from verify.
#      69 target_size = model.input_shape
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\modules\modeling.py:59, in build_model(model_name)
#      57 model = models.get(model_name)
#      58 if model:
# ---> 59     model_obj[model_name] = model()
#      60 else:
#      61     raise ValueError(f"Invalid model_name passed - {model_name}")
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\basemodels\VGGFace.py:45, in VggFaceClient.__init__(self)
#      44 def __init__(self):
# ---> 45     self.model = load_model()
#      46     self.model_name = "VGG-Face"
#      47     self.input_shape = (224, 224)
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\deepface\basemodels\VGGFace.py:158, in load_model(url)
#     153 base_model_output = Flatten()(model.layers[-5].output)
#     154 # keras backend's l2 normalization layer troubles some gpu users (e.g. issue 957, 966)
#     155 # base_model_output = Lambda(lambda x: K.l2_normalize(x, axis=1), name="norm_layer")(
#     156 #     base_model_output
#     157 # )
# --> 158 vgg_face_descriptor = Model(inputs=model.input, outputs=base_model_output)
#     160 return vgg_face_descriptor
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\keras\src\ops\operation.py:228, in Operation.input(self)
#     218 @property
#     219 def input(self):
#     220     """Retrieves the input tensor(s) of a symbolic operation.
#     221
#     222     Only returns the tensor(s) corresponding to the *first time*
#    (...)
#     226         Input tensor or list of input tensors.
#     227     """
# --> 228     return self._get_node_attribute_at_index(0, "input_tensors", "input")
#
# File c:\Users\Iga Miller\OneDrive\Pulpit\Studia_mgr_SI\Sem3\Biometria\Proj3\.venv\lib\site-packages\keras\src\ops\operation.py:259, in Operation._get_node_attribute_at_index(self, node_index, attr, attr_name)
#     243 """Private utility to retrieves an attribute (e.g. inputs) from a node.
#     244
#     245 This is used to implement the properties:
#    (...)
#     256     The operation's attribute `attr` at the node of index `node_index`.
#     257 """
#     258 if not self._inbound_nodes:
# --> 259     raise ValueError(
#     260         f"The layer {self.name} has never been called "
#     261         f"and thus has no defined {attr_name}."
#     262     )
#     263 if not len(self._inbound_nodes) > node_index:
#     264     raise ValueError(
#     265         f"Asked to get {attr_name} at node "
#     266         f"{node_index}, but the operation has only "
#     267         f"{len(self._inbound_nodes)} inbound nodes."
#     268     )
#
# ValueError: The layer sequential_6 has never been called and thus has no defined input.
